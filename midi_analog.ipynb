# %%
import pandas as pd

# %%
import midi

# %%
for i in range(0, len(midi.avail_machines_by_channel)):
    for j in midi.avail_machines_by_channel[i]:
        print(i, j+1, midi.synths[j])
# Out:
# 0 1 Synth, BD hard
# 0 14 Synth, BD FM
# 0 22 Synth, BD plastic
# 0 23 Synth, BD silky
# 0 27 Synth, BD sharp
# 1 1 Synth, BD hard
# 1 2 Synth, BD classic
# 1 3 Synth, SD hard
# 1 14 Synth, BD FM
# 1 15 Synth, SD FM
# 1 16 Synth, noise
# 1 17 Synth, impulse
# 1 22 Synth, BD plastic
# 1 23 Synth, BD silky
# 1 27 Synth, BD sharp
# 1 29 Synth, Dual VCO
# 2 1 Synth, BD hard
# 2 2 Synth, BD classic
# 2 3 Synth, SD hard
# 2 4 Synth, SD classic
# 2 5 Synth, RS hard
# 2 6 Synth, RS classic
# 2 14 Synth, BD FM
# 2 15 Synth, SD FM
# 2 16 Synth, noise
# 2 17 Synth, impulse
# 2 22 Synth, BD plastic
# 2 23 Synth, BD silky
# 2 27 Synth, BD sharp
# 2 29 Synth, Dual VCO
# 3 1 Synth, BD hard
# 3 2 Synth, BD classic
# 3 3 Synth, SD hard
# 3 4 Synth, SD classic
# 3 5 Synth, RS hard
# 3 6 Synth, RS classic
# 3 14 Synth, BD FM
# 3 15 Synth, SD FM
# 3 16 Synth, noise
# 3 17 Synth, impulse
# 3 22 Synth, BD plastic
# 3 23 Synth, BD silky
# 3 27 Synth, BD sharp
# 3 29 Synth, Dual VCO
# 4 8 Synth, BT classic
# ...

# %%
for i in range(0,len(midi.synths)):
    print(i, i+1, midi.synths[i])
# Out:
# 0 1 Synth, BD hard
# 1 2 Synth, BD classic
# 2 3 Synth, SD hard
# 3 4 Synth, SD classic
# 4 5 Synth, RS hard
# 5 6 Synth, RS classic
# 6 7 Synth, CP classic
# 7 8 Synth, BT classic
# 8 9 Synth, LT, MT, HT classic
# 9 10 Synth, CH classic
# 10 11 Synth, OH classic
# 11 12 Synth, CY classic
# 12 13 Synth, CB classic and metallic
# 13 14 Synth, BD FM
# 14 15 Synth, SD FM
# 15 16 Synth, noise
# 16 17 Synth, impulse
# 17 18 Synth, CH metallic
# 18 19 Synth, OH metallic
# 19 20 Synth, CY metallic
# 20 21 Synth, CB classic and metallic
# 21 22 Synth, BD plastic
# 22 23 Synth, BD silky
# 23 24 Synth, SD natural
# 24 25 Synth, HH basic
# 25 26 Synth, CY ride
# 26 27 Synth, BD sharp
# 27 28
# 28 29 Synth, Dual VCO

# %%
rdf = pd.read_csv("Rytm MKII.csv")

# %%
rdf.columns
# Out:
# Index(['manufacturer', 'device', 'section', 'parameter_name',
#        'parameter_description', 'cc_msb', 'cc_lsb', 'cc_min_value',
#        'cc_max_value', 'nrpn_msb', 'nrpn_lsb', 'nrpn_min_value',
#        'nrpn_max_value', 'orientation', 'notes', 'usage'],
#       dtype='object')

# %%
rdf
# Out:
#     manufacturer     device         section parameter_name  \
# 0       Elektron  Rytm MKII            Trig           Note
# 1       Elektron  Rytm MKII            Trig       Velocity
# 2       Elektron  Rytm MKII            Trig         Length
# 3       Elektron  Rytm MKII            Trig     Synth trig
# 4       Elektron  Rytm MKII            Trig    Sample trig
# ..           ...        ...             ...            ...
# 266     Elektron  Rytm MKII    Synth, noise         Attack
# 267     Elektron  Rytm MKII  Synth, impulse          Level
# 268     Elektron  Rytm MKII  Synth, impulse         Attack
# 269     Elektron  Rytm MKII  Synth, impulse          Decay
# 270     Elektron  Rytm MKII  Synth, impulse       Polarity
#
#      parameter_description  cc_msb  cc_lsb  cc_min_value  cc_max_value  \
# 0                      NaN       3     NaN             0           127
# 1                      NaN       4     NaN             0           127
# ...

# %%
#rdf[rdf['section'] == 'Trig']

# %%
rdf[rdf['section'] == 'Kit']
# Out:
#    manufacturer     device section          parameter_name  \
# 7      Elektron  Rytm MKII     Kit             Track level
# 8      Elektron  Rytm MKII     Kit  Track mute (seq. mute)
# 9      Elektron  Rytm MKII     Kit  Track solo (seq. mute)
# 10     Elektron  Rytm MKII     Kit      Track machine type
# 11     Elektron  Rytm MKII     Kit            Active scene
#
#     parameter_description  cc_msb  cc_lsb  cc_min_value  cc_max_value  \
# 7                     NaN      95     NaN             0           127
# 8                     NaN      94     NaN             0           127
# 9                     NaN      93     NaN             0           127
# 10                    NaN      15     NaN             0           127
# 11                    NaN      92     NaN             0           127
#
#     nrpn_msb  nrpn_lsb  nrpn_min_value  nrpn_max_value orientation  notes  \
# 7        1.0     100.0             0.0           127.0     0-based    NaN
# ...

# %%
rdf['section'].unique()
# Out:
# array(['Trig', 'Kit', 'Performance', 'Synth, general', 'Sample', 'Filter',
#        'Amp', 'LFO', 'FX', 'Reverb', 'Distortion', 'Compressor',
#        'Synth, BD plastic', 'Synth, BD sharp', 'Synth, BD hard',
#        'Synth, BD classic', 'Synth, BD FM', 'Synth, BD silky',
#        'Synth, SD natural', 'Synth, SD hard', 'Synth, SD classic',
#        'Synth, SD FM', 'Synth, RS hard', 'Synth, RS classic',
#        'Synth, CP classic', 'Synth, Dual VCO', 'Synth, BT classic',
#        'Synth, LT, MT, HT classic', 'Synth, CH classic',
#        'Synth, CH metallic', 'Synth, OH classic', 'Synth, OH metallic',
#        'Synth, HH basic', 'Synth, CY metallic', 'Synth, CY classic',
#        'Synth, CY ride', 'Synth, CB classic and metallic', 'Synth, noise',
#        'Synth, impulse'], dtype=object)

# %%
synths = rdf[rdf['section'].str.startswith('Synth')]['section'].unique()

# %%
synths
# Out:
# array(['Synth, general', 'Synth, BD plastic', 'Synth, BD sharp',
#        'Synth, BD hard', 'Synth, BD classic', 'Synth, BD FM',
#        'Synth, BD silky', 'Synth, SD natural', 'Synth, SD hard',
#        'Synth, SD classic', 'Synth, SD FM', 'Synth, RS hard',
#        'Synth, RS classic', 'Synth, CP classic', 'Synth, Dual VCO',
#        'Synth, BT classic', 'Synth, LT, MT, HT classic',
#        'Synth, CH classic', 'Synth, CH metallic', 'Synth, OH classic',
#        'Synth, OH metallic', 'Synth, HH basic', 'Synth, CY metallic',
#        'Synth, CY classic', 'Synth, CY ride',
#        'Synth, CB classic and metallic', 'Synth, noise', 'Synth, impulse'],
#       dtype=object)

# %%
pd.Series(synths).to_clipboard(index=False)

# %%
synths = pd.Series(synths)

# %%
#synths = synths[1:].tolist()

# %%
synths
# Out:
# 0                     Synth, general
# 1                  Synth, BD plastic
# 2                    Synth, BD sharp
# 3                     Synth, BD hard
# 4                  Synth, BD classic
# 5                       Synth, BD FM
# 6                    Synth, BD silky
# 7                  Synth, SD natural
# 8                     Synth, SD hard
# 9                  Synth, SD classic
# 10                      Synth, SD FM
# 11                    Synth, RS hard
# 12                 Synth, RS classic
# 13                 Synth, CP classic
# 14                   Synth, Dual VCO
# 15                 Synth, BT classic
# 16         Synth, LT, MT, HT classic
# 17                 Synth, CH classic
# 18                Synth, CH metallic
# 19                 Synth, OH classic
# 20                Synth, OH metallic
# 21                   Synth, HH basic
# 22                Synth, CY metallic
# 23                 Synth, CY classic
# 24                    Synth, CY ride
# ...

# %%
rdf[~rdf['section'].isin(synths)]
# Out:
#    manufacturer     device     section            parameter_name  \
# 0      Elektron  Rytm MKII        Trig                      Note
# 1      Elektron  Rytm MKII        Trig                  Velocity
# 2      Elektron  Rytm MKII        Trig                    Length
# 3      Elektron  Rytm MKII        Trig                Synth trig
# 4      Elektron  Rytm MKII        Trig               Sample trig
# ..          ...        ...         ...                       ...
# 87     Elektron  Rytm MKII  Compressor    Compressor makeup gain
# 88     Elektron  Rytm MKII  Compressor          Compressor ratio
# 89     Elektron  Rytm MKII  Compressor   Compressor sidechain EQ
# 90     Elektron  Rytm MKII  Compressor    Compressor dry/wet mix
# 91     Elektron  Rytm MKII  Compressor  Compressor output volume
#
#     parameter_description  cc_msb  cc_lsb  cc_min_value  cc_max_value  \
# 0                     NaN       3     NaN             0           127
# ...

# %%
non_kit = rdf[~rdf['section'].isin(synths)]['section'].unique()

# %%
non_kit
# Out:
# array(['Trig', 'Kit', 'Performance', 'Sample', 'Filter', 'Amp', 'LFO',
#        'FX', 'Reverb', 'Distortion', 'Compressor'], dtype=object)

# %%
rdf[rdf['section'] == 'LFO']
# Out:
#    manufacturer     device section   parameter_name  parameter_description  \
# 56     Elektron  Rytm MKII     LFO        LFO speed                    NaN
# 57     Elektron  Rytm MKII     LFO   LFO multiplier                    NaN
# 58     Elektron  Rytm MKII     LFO  LFO fade in/out                    NaN
# 59     Elektron  Rytm MKII     LFO  LFO destination                    NaN
# 60     Elektron  Rytm MKII     LFO     LFO waveform                    NaN
# 61     Elektron  Rytm MKII     LFO  LFO start phase                    NaN
# 62     Elektron  Rytm MKII     LFO    LFO trig mode                    NaN
# 63     Elektron  Rytm MKII     LFO        LFO depth                    NaN
#
#     cc_msb  cc_lsb  cc_min_value  cc_max_value  nrpn_msb  nrpn_lsb  \
# 56     102     NaN             0           127       1.0      32.0
# 57     103     NaN             0           127       1.0      33.0
# 58     104     NaN             0           127       1.0      34.0
# ...

# %%
pd.Series(non_kit).to_clipboard(index=False)

# %%
bd_classic = rdf['section'] == synths[3]
rdf[bd_classic]
# Out:
#     manufacturer     device         section  parameter_name  \
# 108     Elektron  Rytm MKII  Synth, BD hard           Level
# 109     Elektron  Rytm MKII  Synth, BD hard            Tune
# 110     Elektron  Rytm MKII  Synth, BD hard           Decay
# 111     Elektron  Rytm MKII  Synth, BD hard            Hold
# 112     Elektron  Rytm MKII  Synth, BD hard      Sweep time
# 113     Elektron  Rytm MKII  Synth, BD hard     Sweep depth
# 114     Elektron  Rytm MKII  Synth, BD hard        Waveform
# 115     Elektron  Rytm MKII  Synth, BD hard  Transient tick
#
#      parameter_description  cc_msb  cc_lsb  cc_min_value  cc_max_value  \
# 108                    NaN      16     NaN             0           127
# 109                    NaN      17     NaN             0           127
# 110                    NaN      18     NaN             0           127
# 111                    NaN      19     NaN             0           127
# ...

# %%
synths
# Out:
# ['Synth, BD plastic',
#  'Synth, BD sharp',
#  'Synth, BD hard',
#  'Synth, BD classic',
#  'Synth, BD FM',
#  'Synth, BD silky',
#  'Synth, SD natural',
#  'Synth, SD hard',
#  'Synth, SD classic',
#  'Synth, SD FM',
#  'Synth, RS hard',
#  'Synth, RS classic',
#  'Synth, CP classic',
#  'Synth, Dual VCO',
#  'Synth, BT classic',
#  'Synth, LT, MT, HT classic',
#  'Synth, CH classic',
#  'Synth, CH metallic',
#  'Synth, OH classic',
#  'Synth, OH metallic',
#  'Synth, HH basic',
#  'Synth, CY metallic',
#  'Synth, CY classic',
#  'Synth, CY ride',
#  'Synth, CB classic and metallic',
#  'Synth, noise',
#  'Synth, impulse']

# %%
rdf[~bd_classic]
# Out:
#     manufacturer     device         section parameter_name  \
# 0       Elektron  Rytm MKII            Trig           Note
# 1       Elektron  Rytm MKII            Trig       Velocity
# 2       Elektron  Rytm MKII            Trig         Length
# 3       Elektron  Rytm MKII            Trig     Synth trig
# 4       Elektron  Rytm MKII            Trig    Sample trig
# ..           ...        ...             ...            ...
# 266     Elektron  Rytm MKII    Synth, noise         Attack
# 267     Elektron  Rytm MKII  Synth, impulse          Level
# 268     Elektron  Rytm MKII  Synth, impulse         Attack
# 269     Elektron  Rytm MKII  Synth, impulse          Decay
# 270     Elektron  Rytm MKII  Synth, impulse       Polarity
#
#      parameter_description  cc_msb  cc_lsb  cc_min_value  cc_max_value  \
# 0                      NaN       3     NaN             0           127
# 1                      NaN       4     NaN             0           127
# ...

# %%
len(synths)
# Out:
# 28

# %%
synths
# Out:
# 0                     Synth, general
# 1                  Synth, BD plastic
# 2                    Synth, BD sharp
# 3                     Synth, BD hard
# 4                  Synth, BD classic
# 5                       Synth, BD FM
# 6                    Synth, BD silky
# 7                  Synth, SD natural
# 8                     Synth, SD hard
# 9                  Synth, SD classic
# 10                      Synth, SD FM
# 11                    Synth, RS hard
# 12                 Synth, RS classic
# 13                 Synth, CP classic
# 14                   Synth, Dual VCO
# 15                 Synth, BT classic
# 16         Synth, LT, MT, HT classic
# 17                 Synth, CH classic
# 18                Synth, CH metallic
# 19                 Synth, OH classic
# 20                Synth, OH metallic
# 21                   Synth, HH basic
# 22                Synth, CY metallic
# 23                 Synth, CY classic
# 24                    Synth, CY ride
# ...

# %%
import mido

# %%
mido.get_output_names()[0]
# Out:
# 'Elektron Analog Rytm MKII'

# %%
#p = mido.open_output('Elektron Analog Rytm MKII Analog Rytm MKII out 1')

# %%
p = mido.open_output('Elektron Analog Rytm MKII')

# %%
p
# Out:
# <open output 'Elektron Analog Rytm MKII' (RtMidi/MACOSX_CORE)>

# %% [markdown]
#  * 0 - BD Hard
#  * 1 - BD Classic
#  * 2 - SD Hard
#  * 3 - SD classic
#  * 9 - CH Classic
#  * 13 - BD FM
#  * 14 - SD FM
#  * 15 - Noise gen
#  * 16 - Impulse
#  * 21 - BD plastic
#  * 22 - BD Silky
#  * 23 - SD Natural
#  * 26 - BD Sharp
#  * 27 - Disable
#  * 28 - Dual VCO

# %%
kicks = [0,1,13,14,21,22,26]

# %%
snares = [0,1,2,3,13,14,15,16,21,22,23,26,28]

# %%
cc=15
channel=9
value=9
msg = mido.Message(type='control_change', channel=channel, control=cc, value=value, time=time)
p.send(msg)

# %%
cc=15
channel=10
value=13
msg = mido.Message(type='control_change', channel=channel, control=cc, value=value, time=time)
p.send(msg)

# %%
note = 60
time=100
m2 = mido.Message('note_on', note=note, channel=channel)

p.send(m2)

# %%
m3 = mido.Message('note_off', note=note, channel=channel)
p.send(m3)
